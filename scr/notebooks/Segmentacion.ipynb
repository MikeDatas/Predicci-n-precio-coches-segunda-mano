# %%
# Tercer paso, después del EDA, segmentación de los modelos.

# %%
import pandas as pd
import numpy as np
# import sys
# sys.path.append("../")

# %%
df = pd.read_csv("../data/data_limpio.csv")

# %%
df
# Out:
#           make       model      fuel  year       kms  power      shift  price
# 0         Opel   Crossland  Gasolina  2022   24847.0  110.0     manual  19990
# 1         Opel   Crossland    Diésel  2021   41356.0  120.0  automatic  18590
# 2         Opel   Crossland  Gasolina  2021   51390.0  110.0     manual  18200
# 3         Opel   Crossland  Gasolina  2021   30536.0  110.0     manual  17100
# 4         Opel   Crossland  Gasolina  2019   40816.0   83.0     manual  13490
# ...        ...         ...       ...   ...       ...    ...        ...    ...
# 11180  Citroen  C4 Picasso  Gasolina  2012  103700.0  120.0     manual   8500
# 11181  Citroen  C4 Picasso    Diésel  2017   71330.0  120.0     manual  18200
# 11182  Citroen  C4 Picasso    Diésel  2014  109350.0  150.0     manual  11690
# 11183  Citroen  C4 Picasso  Gasolina  2017  108697.0  130.0     manual  13199
# 11184  Citroen  C4 Picasso    Diésel  2012  178131.0  110.0     manual   7950
#
# [11185 rows x 8 columns]

# %%
def clasificar_vehiculo_df(row, clasificaciones):
    """
    Clasifica un vehículo en un segmento basándose en la marca y el modelo de una fila del DataFrame.

    Args:
        row (pandas.Series): Una fila del DataFrame con las columnas 'make' y 'model'.
        clasificaciones (dict): Un diccionario donde las claves son los segmentos
                                y los valores son listas de modelos (en minúsculas) pertenecientes a ese segmento.

    Returns:
        str or None: El segmento al que pertenece el vehículo, o None si no se encuentra.
    """
    marca = row['make'].lower()
    modelo = row['model'].lower()
    nombre_completo = f"{marca} {modelo}"

    for segmento, modelos in clasificaciones.items():
        for patron in modelos:
            if patron in nombre_completo:
                return segmento
    return None

# Actualizamos el diccionario de clasificaciones con los 100 vehículos adicionales
clasificaciones_segmentos = {
    #Segmento A: Minicompactos
    "A": [
        "opel karl", "nissan micra", "nissan note", "renault twingo", "fiat panda",
        "mitsubishi space star", "kia picanto", "toyota aygo", "suzuki ignis", "hyundai i10",
        "opel adam", "renault twizy", "nissan pixo", "toyota iq", "toyota aygo x",
        "citroen c2", "citroen c1", "fiat ka", "chevrolet matiz", "kia picanto",
        "volkswagen fox", "peugeot 108", "peugeot 107", "fiat seicento", "citroen c-zero",
        "daewoo matiz", "chevrolet spark", "subaru justy", "vaz 110", "seat mii electric", "opel agila",
        "peugeot 1007",
        "volkswagen beetle",
        "peugeot 106",
        "citroen saxo",
        "volkswagen lupo", "audi a2",
        "citroen nemo",
        "fiat qubo",
        "ford tourneo courier",
        "ford transit courier",
        "lancia musa",
        "peugeot bipper","nissan kubistar",
        "citroen c 15"
    ],
    #Segmento B: Coches pequeño
    "B": [
        "opel crossland", "opel corsa-e", "opel corsa", "rover 45", "ssangyong tivoli",
        "mini paceman", "kia soul", "kia stonic", "nissan juke", "renault captur",
        "renault clio", "seat ibiza", "jeep renegade", "abarth 595", "abarth 500",
        "volvo xc40", "citroen c3", "peugeot 208", "ford fiesta", "renault zoe",
        "hyundai i20", "toyota yaris", "skoda fabia", "dacia sandero", "mazda 2",
        "opel meriva", "skoda kamiq", "kia rio", "kia venga", "infiniti q30",
        "toyota yaris cross", "land rover range rover evoque", "daihatsu terios",
        "dacia logan", "dacia sandero", "citroen c3 picasso", "audi a1",
        "alfa romeo mito", "suzuki ignis", "honda jazz", "hyundai getz", "hyundai atos",
        "hyundai bayon", "hyundai kona", "ford ka", "ford puma", "ford fiesta",
        "peugeot e-208", "mg zs", "mg zr", "lancia ypsilon", "chevrolet aveo",
        "peugeot 207", "volkswagen polo", "fiat 500", "mazda cx-3", "peugeot 2008",
        "volvo v40", "kia cerato", "hyundai accent", "rover 25", "ford escort","nissan tiida",
        "chevrolet kalos",
        "daewoo kalos",
        "peugeot 206",
        "daewoo lanos",
        "kia shuma", "renault modus",
        "fiat linea",
        "fiat sedici",
        "kia niro",
        "kia xceed",
        "cupra born",
        "dacia jogger","bmw i3"
    ],
    #Segmento C: Compactos
    "C": [
        "opel ampera", "ssangyong korando", "kia ceed", "kia sportage",
        "mitsubishi eclipse cross", "nissan pulsar", "renault scenic", "renault arkana",
        "renault kadjar", "renault megane", "seat tarraco", "seat toledo", "seat leon",
        "skoda yeti", "skoda octavia", "jeep compass", "opel astra", "kia proceed",
        "saab 9-3", "volvo s60", "citroen c4 cactus", "peugeot 308", "ford focus",
        "hyundai i30", "toyota auris", "suzuki vitara", "nissan qashqai", "bmw serie 1",
        "audi a3", "mercedes-benz clase a", "lexus ct", "infiniti q30", "toyota corolla",
        "daewoo lacetti", "chevrolet lacetti", "alfa romeo giulietta", "volvo s40",
        "audi rs q3", "ds 4", "audi a4", "tata indica", "fiat punto", "skoda karoq",
        "alfa romeo gt", "audi q2", "audi a5", "audi s3", "audi q3", "audi s1",
        "citroen ds3", "citroen ds4", "cupra leon", "honda civic", "hyundai elantra",
        "ford c-max", "peugeot 308", "subaru xv", "volkswagen id.3", "volkswagen golf",
        "audi rs3", "opel signum", "mg zr", "chevrolet cruze", "alfa romeo 146",
        "alfa romeo 145", "alfa romeo 147", "mazda 3", "fiat bravo", "fiat stilo",
        "citroen c4", "lancia delta", "peugeot 307", "citroen xsara", "opel vectra",
        "alfa romeo 156", "volkswagen bora", "chevrolet nubira",
        "ds 3",
        "fiat tipo",
        "volvo v50",
        "peugeot 306",
        "volkswagen taigo",
        "volkswagen t-cross",
        "nissan almera",
        "suzuki baleno","mitsubishi lancer",
        "nissan leaf",
        "toyota prius",
        "alfa romeo tonale",
        "citroen ë-c4",
        "dodge avenger",
        "hyundai ioniq",
        "volvo c40", "citroen xantia"
    ],
    #Segmento D: coches grandes
    "D": [
        "opel insignia", "opel omega", "tesla model 3", "lexus is", "nissan primera",
        "renault talisman", "renault fluence", "renault laguna", "seat exeo",
        "saab 9-5", "volvo v90", "volvo xc70", "citroen c5", "peugeot 508",
        "ford mondeo", "hyundai i40", "toyota avensis", "skoda superb", "vw passat",
        "audi a4", "bmw serie 3", "mercedes-benz clase c", "jaguar xe", "rover 75",
        "lexus es", "kia optima", "infiniti q70", "infiniti g37", "infiniti q50",
        "lancia thema", "jaguar xf", "daewoo nubira", "chevrolet epica",
        "cadillac seville", "chrysler 300 c", "audi a6", "audi a6 allroad", "audi rs6",
        "audi rs7", "volvo s90", "jaguar xj", "peugeot traveller", "alfa romeo 159",
        "alfa romeo 166", "alfa romeo giulia", "audi s8", "audi s6", "audi a4 allroad",
        "audi s4", "citroen c6", "citroen c-élysée", "honda insight", "ford fusion",
        "mazda 6", "volkswagen arteon", "subaru levorg", "chrysler sebring",
        "volkswagen jetta", "subaru legacy", "chrysler stratus", "volkswagen cc",
        "toyota camry", "hyundai sonata", "volkswagen phaeton", "chevrolet alero",
        "citroen c5 x", "mazda 626", "peugeot 607", "volkswagen passat",
        "kia magentis", "nissan maxima", "renault vel satis", "citroen xm",
        "mercedes-benz clase e", "jaguar x-type", "opel vectra", "chevrolet malibu",
        "hyundai xg", "renault latitude",
        "peugeot 407",
        "honda accord",
        "chrysler 300 m",
        "kia opirus",
        "jaguar daimler",
        "jaguar s-type",
        "fiat croma",
        "honda legend",
        "hyundai grandeur",
        "lancia kappa",
        "mazda xedos 9",
        "lancia thesis","ds 7 crossback",
        "mercedes-benz clase b","dodge journey"
    ],
    #Segmento E: coches de prestigio
    "E": [
        "lexus gs", "volvo xc90", "volvo xc60", "renault grand espace", "audi a6",
        "bmw serie 5", "mercedes-benz clase e", "jaguar xf", "volvo s80", "volvo v60",
        "tesla model s", "maserati ghibli", "maserati quattroporte", "lexus ls",
        "infiniti qx50", "infiniti fx30", "audi a7", "bmw x6 m", "jaguar xj",
        "chrysler 300 c", "audi sq5", "citroen ds5", "volvo s90",
        "mercedes-benz clase cla", "bmw serie 8", "bmw serie 6", "mercedes-benz gle",
        "mercedes-benz glc coupé", "mercedes-benz gle coupé", "audi a8", "audi s7",
        "volvo s70", "lexus rc", "infiniti ex30", "jaguar xkr", "jaguar xk series",
        "ds 5", "bmw z3", "mercedes-benz sl",
        "mercedes-benz classe glk", "mercedes-benz clase r", "mercedes-benz gl",
        "bmw x1", "bmw x5", "bmw x7", "bmw ix3", "bmw serie 5", "volvo v70",
        "jaguar xk8", "mercedes-benz cl coupe", "jaguar i-pace", "cadillac cts",
        "mercedes-benz clase cls", "infiniti ex37", "renault vel satis",
        "mercedes-benz eqv","audi s5","mercedes-benz clk",
        "infiniti q60"
        
    ],
    #Segmento F: coches de lujo
    "F": [
        "tesla model x", "tesla model y", "audi a8", "bmw serie 7", "mercedes-benz clase s",
        "porsche panamera", "maserati levante", "maserati coupe", "maserati granturismo",
        "lexus lc", "land rover range rover", "bentley (varios modelos)", "rolls-royce (varios modelos)",
        "ferrari 458", "cadillac escalade", "audi rs5", "audi r8", "aston martin vanquish",
        "aston martin db9", "audi q8", "audi sq7", "audi e-tron gt", "bentley arnage",
        "bentley continental", "bentley mulsanne", "bentley bentayga", "chevrolet camaro",
        "alfa romeo 4c", "mercedes-benz clase g", "aston martin db11", "ferrari 360",
        "ferrari f430", "audi sq8", "aston martin vantage", "alfa romeo brera",
        "lamborghini gallardo", "lamborghini murcielago", "mercedes-benz amg gt",
        "bmw i8", "bentley flying spur", "aston martin dbx", "alfa romeo gtv",
        "audi rs q8", "dodge viper", "jaguar f-type", "maserati grancabrio",
        "maserati 3200 gt", "ferrari f599", "lotus evora", "lotus esprit",
        "lexus rc f", "lotus exige", "ferrari portofino", "lexus sc", "lotus elise",
        "lexus is f", "lamborghini aventador", "mercedes-benz slr",
        "chevrolet corvette","ferrari california",
        "ferrari 488",
        "porsche 718 boxster",
        "porsche cayman",
        "ktm x-bow",
        "mg tf",
        "honda s2000",
        "lamborghini huracán",
        "fiat barchetta",
        "ferrari laferrari",
        "ferrari 456",
        "ferrari ff",
        "ferrari 612 scaglietti",
        "ferrari roma",
        "ferrari f8",
        "corvette corvette",
        "nissan gt-r","maserati grecale","porsche 911","bentley bentayga",
    ],
    #Segmento J: SUV
    "J": [
        "opel antara", "mini paceman", "kia sorento", "lexus nx", "lexus rx",
        "mitsubishi outlander", "nissan x-trail", "nissan terrano", "renault koleos",
        "jeep cherokee", "volvo xc40", "citroen c4 aircross", "peugeot 3008",
        "ford kuga", "hyundai ix35", "toyota c-hr", "suzuki s-cross", "dacia duster",
        "bmw x1", "audi q3", "mercedes-benz gla", "porsche cayenne", "porsche macan",
        "ssangyong kyron", "ssangyong xlv", "jeep wrangler", "jeep patriot",
        "lexus ux", "infiniti qx50", "infiniti qx70", "infiniti qx30",
        "toyota land cruiser 150", "land rover range rover velar",
        "land rover range rover sport", "land rover discovery",
        "land rover freelander", "land rover discovery sport", "jaguar e-pace",
        "jaguar f-pace", "daihatsu terios", "skoda kodiaq", "skoda karoq",
        "honda cr-v", "bmw x6 m", "toyota land cruiser", "audi sq5", "alfa romeo stelvio",
        "audi q4", "audi q5", "audi sq7", "chevrolet trax",
        "citroen c4 aircross", "citroen jumpy", "citroen c3 aircross", "cupra formentor",
        "cupra ateca", "dodge nitro", "honda hr-v", "hyundai ix35", "hyundai kona",
        "hyundai ix55", "hyundai grand santa fe", "mercedes-benz glc coupé",
        "mercedes-benz gle coupé", "mercedes-benz gle", "bmw x3", "bmw x2", "bmw x5 m",
        "bmw x6", "bmw ix", "bmw x4", "ford edge", "ford explorer", "ford ecosport",
        "citroen c5 aircross", "hyundai ioniq 5", "peugeot 5008", "mazda cx-9",
        "mazda cx-30", "mazda cx-5", "peugeot e-2008", "subaru xv", "volkswagen id.4",
        "subaru impreza", "suzuki jimny", "volkswagen tiguan", "volkswagen t-roc",
        "audi e-tron", "toyota highlander", "citroen c-crosser", "chevrolet captiva",
        "audi q7", "audi sq2", "kia e-niro", "peugeot 4007", "hyundai tucson",
        "hyundai santa fe", "dodge caliber", "mercedes-benz gl", "bmw x5", "bmw ix3", "subaru tribeca",
        "volkswagen tiguan allspace", "subaru outback", "suzuki grand vitara",
        "aston martin dbx", "jeep grand cherokee", "toyota urban cruiser",
        "hyundai veloster", "isuzu d-max", "iveco massif", "peugeot 4008",
        "mahindra xuv 500", "volkswagen id.5", "land rover defender",
        "toyota land cruiser 90", "jeep commander", "jeep gladiator", "hummer h3",
        "santana 300", "mg marvel r", "mg ehs", "citroen e-mehari",
        "hyundai genesis coupe", "kia ev6","Opel Grandland X",
        "opel grandland x",
        "opel grandland",
        "mazda mx-30",
        "volkswagen touareg",
        "hyundai terracan",
        "chevrolet tahoe",
        "mercedes-benz gl",
        "lamborghini urus",
        "nissan patrol",
        "opel mokka",
        "opel mokka x",
        "nissan murano",
        "ds 3 crossback",
        "hyundai ix20",
        "nissan pathfinder",
        "mazda cx-7",
        "mercedes-benz clase gle",
        "alfa romeo stelvio",
        "hummer h2",
        "galloper super exceed",
        "lada niva",
        "galloper exceed",
        "tata safari", "opel frontera",
        "tata grand safari",
        "nissan murano", 
        "mercedes-benz  gle",
        "ds 7 crossback","mercedes-benz gl","mercedes-benz classe x","nissan pick-up"
    ],
    #Segmento M: Familiares grandes
    "M": [
        "opel combo", "opel movano", "opel vivaro", "opel combo life", "nissan primastar",
        "renault master", "renault grand scenic", "renault trafic", "renault grand espace",
        "renault kangoo", "citroen berlingo", "peugeot partner", "ford s-max",
        "volvo v90", "skoda octavia combi", "vw touran", "seat alhambra",
        "fiat doblo", "toyota verso", "hyundai trajet", "kia carens", "dacia dokker",
        "renault express van", "renault grand kangoo", "renault espace",
        "nissan vanette", "vw passat alltrack", "mitsubishi space gear", "lancia voyager",
        "daewoo tacuma", "dacia lodgy", "citroen spacetourer",
        "citroen grand c4 spacetourer", "citroen c4 spacetourer", "chevrolet orlando",
        "mazda premacy", "peugeot traveller", "citroen partner", "audi a6 allroad",
        "volvo v60", "citroen jumper", "mercedes-benz clase v", "mercedes-benz citan",
        "mercedes-benz sprinter", "mercedes-benz vito", "mercedes-benz marco polo",
        "fiat fiorino", "toyota previa",
        "fiat multipla",
        "ford galaxy",
        "volkswagen sharan",
        "peugeot 807",
        "fiat ulysse",
        "chrysler grand voyager",
        "lancia phedra",
        "mitsubishi grandis",
        "mazda mpv",
        "kia carnival",
        "opel zafira tourer",
        "nissan evalia",
        "chrysler voyager",
        "volkswagen caravelle",
        "citroen grand c4 picasso",
        "ford grand c-max",
        "mazda 5",
        "volkswagen touran",
        "dacia jogger",
        "opel zafira",
        "nissan nv200",
        "honda fr-v",
        "fiat idea",
        "ford b-max",
        "chrysler pt cruiser",
        "chevrolet hhr",
        "hyundai matrix",
        "chevrolet tacuma",
        "mitsubishi space wagon",
        "ford grand tourneo connec", "nissan nv200",
        "fiat doblò",
        "fiat freemont",
        "ford grand c-max",
        "mazda 5", 
        "volkswagen touran",
        "nissan evalia",
        "citroen c8"
    ],
    #Segmento S: Deportivos
      "S": [
        "opel cabrio", "opel tigra", "abarth 595", "abarth 500",
        "toyota mr2", "bmw z4", "audi tt", "volvo c70", "volvo c30", "mini roadster",
        "nissan 370z", "toyota gr supra", "lexus lc", "kia stinger", "infiniti m30",
        "ferrari 458", "audi rs5", "audi r8", "alfa romeo 4c", "abarth 695",
        "alpine a110", "alfa romeo spider",
        "audi s8", "audi s6", "audi tt", "audi rs4", "chevrolet camaro",
        "honda cr-z", "hyundai coupe", "fiat 124 spider", "ford mustang",
        "porsche 718 cayman", "mazda mx-5", "peugeot rcz", "bmw z3",
        "dodge viper", "alfa romeo gtv", "peugeot rc", "ford cougar","mitsubishi 3000 gt",
        "volkswagen eos",
        "volkswagen scirocco",
        "opel speedster",
        "renault wind",
        "nissan 350z",
        "subaru wrx",
        "bmw serie 4",
        "abarth 124 spider",
        "bmw serie 2",
        "abarth punto evo",
        "porsche boxster",
        "porsche taycan","chrysler crossfire","bmw i4",
        "honda prelude"
        ],
        "otros": [
        "mitsubishi l 200",
        "nissan nv300",
        "nissan nv400",
        "nissan navara",
        "nissan nv250",
        "nissan cabstar",
        "nissan townstar",
        "nissan atleon",
        "renault trucks maxity",
        "nissan trade",
        "nissan nt400 cabstar",
        "nissan eco t",
        "nissan np300 navara",
        "toyota hilux",
        "iveco daily",
        "hyundai h350",
        "fiat scudo",
        "fiat talento",
        "fiat e-ducato",
        "ford ranger",
        "ford transit connect",
        "ford transit custom",
        "peugeot expert",
        "peugeot boxer",
        "peugeot rifter",
        "peugeot 406",
        "volkswagen crafter",
        "volkswagen california",
        "volkswagen amarok",
        "volkswagen caddy",
        "volkswagen transporter t6",
        "mercedes-benz gl",
        "mercedes-benz evito",
        "fiat ducato",
        "fiat fullback",
        "ford tourneo custom",
        "volkswagen transporter",
        "volkswagen multivan",
        "volkswagen transporter t5",
        "nissan interstar","ford transit",
        "ford tourneo connect",
        "hyundai h-1",
        "mercedes-benz viano",
        "peugeot e-rifter",
        "citroen ë-berlingo",
        "volkswagen grand california",
        "volkswagen lt35",
        "tata indigo",
        "kia pregio","isuzu nlr",
        "renault express",
        "mercedes-benz esprinter",
        "tata xenon",
        "mitsubishi l 300"
    ]
    }

# %%
# Asumiendo que tu DataFrame df_lean tiene las columnas 'make' y 'model'
df['segmento'] = df.apply(lambda row: clasificar_vehiculo_df(row, clasificaciones_segmentos), axis=1)

# Ahora, df_lean tendrá una nueva columna llamada 'segmento'
# Puedes ver el resultado imprimiendo las primeras filas del DataFrame
#print(df.head())

# O puedes ver la columna 'segmento' completa
#print(df[['make', 'model', 'segmento']])
df
# Out:
#           make       model      fuel  year       kms  power      shift  price  \
# 0         Opel   Crossland  Gasolina  2022   24847.0  110.0     manual  19990
# 1         Opel   Crossland    Diésel  2021   41356.0  120.0  automatic  18590
# 2         Opel   Crossland  Gasolina  2021   51390.0  110.0     manual  18200
# 3         Opel   Crossland  Gasolina  2021   30536.0  110.0     manual  17100
# 4         Opel   Crossland  Gasolina  2019   40816.0   83.0     manual  13490
# ...        ...         ...       ...   ...       ...    ...        ...    ...
# 11180  Citroen  C4 Picasso  Gasolina  2012  103700.0  120.0     manual   8500
# 11181  Citroen  C4 Picasso    Diésel  2017   71330.0  120.0     manual  18200
# 11182  Citroen  C4 Picasso    Diésel  2014  109350.0  150.0     manual  11690
# 11183  Citroen  C4 Picasso  Gasolina  2017  108697.0  130.0     manual  13199
# 11184  Citroen  C4 Picasso    Diésel  2012  178131.0  110.0     manual   7950
#
#       segmento
# 0            B
# ...

# %%
# Comrrobaciones: Filtrar filas donde 'segmento' para ver si hay valores faltantes. Para poder seguir segmentando.

df_missing_segmento = df[df['segmento'].isna()]
df_missing_segmento
# Out:
# Empty DataFrame
# Columns: [make, model, fuel, year, kms, power, shift, price, segmento]
# Index: []

# %%
# Lo filtro para quedarme solo con make y model sin duplicar de los que me falta asignar segmento. 

df_missing_segmento = df_missing_segmento[['make', 'model']].drop_duplicates()
df_missing_segmento
# Out:
# Empty DataFrame
# Columns: [make, model]
# Index: []

# %%
df_missing_segmento.to_numpy()
# Out:
# array([], shape=(0, 2), dtype=object)

# %%
df_segmentado = df.drop(columns="model")

# %%
df_segmentado
# Out:
#           make      fuel  year       kms  power      shift  price segmento
# 0         Opel  Gasolina  2022   24847.0  110.0     manual  19990        B
# 1         Opel    Diésel  2021   41356.0  120.0  automatic  18590        B
# 2         Opel  Gasolina  2021   51390.0  110.0     manual  18200        B
# 3         Opel  Gasolina  2021   30536.0  110.0     manual  17100        B
# 4         Opel  Gasolina  2019   40816.0   83.0     manual  13490        B
# ...        ...       ...   ...       ...    ...        ...    ...      ...
# 11180  Citroen  Gasolina  2012  103700.0  120.0     manual   8500        C
# 11181  Citroen    Diésel  2017   71330.0  120.0     manual  18200        C
# 11182  Citroen    Diésel  2014  109350.0  150.0     manual  11690        C
# 11183  Citroen  Gasolina  2017  108697.0  130.0     manual  13199        C
# 11184  Citroen    Diésel  2012  178131.0  110.0     manual   7950        C
#
# [11185 rows x 8 columns]

# %%
df_segmentado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11185 entries, 0 to 11184
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   make      11185 non-null  object
#  1   fuel      11185 non-null  object
#  2   year      11185 non-null  int64
#  3   kms       11185 non-null  float64
#  4   power     11185 non-null  float64
#  5   shift     11185 non-null  object
#  6   price     11185 non-null  int64
#  7   segmento  11185 non-null  object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 699.2+ KB

# %%
df_segmentado.to_csv('../data/modelos_segmentados.csv', index=False)
